# %%
from rfm_deployment.rfm_model_V2_com import *
from itertools import product
import cx_Oracle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import datetime
import cairo
import gi
gi.require_version('Gtk', '3.0')
from gi.repository import Gtk

# %matplotlib inline

# %%
df = pd.read_csv('RFM_CA-20190525--20190325.csv')

# %%
df.head(10)
# Out:
#           CUIT  RECENCIA  FRECUENCIA      MONTO  R_Quintil  F_Quintil  \
# 0  30715301926         1         552  442620.81          5          5
# 1  30531887596         1         251  196485.38          5          5
# 2  23208683284         1          55   53312.00          5          3
# 3  27368462190         1         103  118000.00          5          4
# 4  30709315923         1         251  116495.49          5          5
# 5  20202382143         1          57   89059.00          5          3
# 6  20109165086         1          32   69530.00          5          2
# 7  27176692745         1          70  115822.00          5          4
# 8  27059760772         7          24   30550.00          1          2
# 9  30711665540         7          43   44177.00          1          3
#
#    M_Quintil  RFMScore  Total_score
# 0          5       555           15
# 1          5       555           15
# 2          2       532           10
# 3          4       544           13
# 4          4       554           14
# 5          3       533           11
# 6          2       522            9
# 7          4       544           13
# 8          1       121            4
# 9          1       131            5

# %%
pd.set_option('display.max_columns', 500)

# %%
inicio = datetime.date(2020, 2, 25)
fin = datetime.date(2019, 3, 25)
months = -1

# %%
fecha_final = add_months(inicio, -2)
contador = 1


trimestre = []
campeones = []
loyals = []
potential_loyal = []
news = []
promising = []
cant_lost = []
risk = []
need_atention = []
close_hibernating = []
hibernating = []

while fecha_final >= fin :
   
    fi_int = datetime_to_integer(inicio)
    ff_int = datetime_to_integer(fecha_final)
    print(f'Ciclo--{contador}:')
    print(f'La fecha de inicio es: {inicio}. La fecha final es: {fecha_final}.' )
    fecha_out = str(ff_int) # Fecha límite inferior para el trimestre de interés
    fecha_in = str(fi_int)  # Fecha límite superior para el trimestre de interés
    label = 'CA'
    df = pd.read_parquet(f'CA-{fecha_in}--{fecha_out}.parquet')
    print('=================================================================================================')
    
    rfm_model = rfm_scoring(df, fecha_in, fecha_out, label)
    print('-------------------------------------------------------------------------------------------------')

    #rfm_corr = rfm_model[['RECENCIA', 'FRECUENCIA', 'MONTO']].corr()
    #print('La matriz de correlacion es:')
    #print(rfm_corr.corr())
    #print('-------------------------------------------------------------------------------------------------')
    
    #bins_R = 90
    #bins_F = 100
    #bins_M = 100
    #range_R = [0,90]
    #range_F = [0, 10000]
    #range_M = [0, 10000000]
    #histogramas(rfm_model['RECENCIA'], rfm_model['FRECUENCIA'], rfm_model['MONTO'], 
    #        bins_R, bins_F, bins_M, range_R, range_F, range_M)

    #EDA...
    #histogramas(rfm['RECENCIA'], rfm['FRECUENCIA'], rfm['MONTO'])
    #print('-------------------------------------------------------------------------------------------------')
    
    segmentar(rfm_model, fecha_in, fecha_out)
    rfm_segmentos, dic_cuit, rfm_segmentado = label_segmentos(rfm_model, fecha_in, fecha_out,label)
    
     #Creando listas para generar gráfico de lineas como función de los trimestres')
   
    entrada = datetime.datetime.strptime(f'{inicio}', '%Y-%m-%d').strftime('%d/%m/%Y')
    salida = datetime.datetime.strptime(f'{fecha_final}', '%Y-%m-%d').strftime('%d/%m/%Y')
   
    trimestre.append(f'{entrada}--{salida}')
    campeones.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Campeones'][['%']].iloc[0,0])
    loyals.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Leales'][['%']].iloc[0,0])
    potential_loyal.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Potencialmente Leales'][['%']].iloc[0,0])
    news.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Reciente operativo'][['%']].iloc[0,0])
    promising.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Prometedores'][['%']].iloc[0,0])
    cant_lost.append(rfm_segmentado[rfm_segmentado['Segment'] == 'No se pueden perder'][['%']].iloc[0,0])
    risk.append(rfm_segmentado[rfm_segmentado['Segment'] == 'En Riesgo'][['%']].iloc[0,0])
    need_atention.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Necesitan Atencion'][['%']].iloc[0,0])
    close_hibernating.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Cercanos a Hibernar'][['%']].iloc[0,0])
    hibernating.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Hibernando'][['%']].iloc[0,0])
      
   
    inicio = add_months(inicio, months)
    fecha_final = add_months(fecha_final, months)
    contador += 1
   
    print('=================================================================================================')
    
print('Evolución trimestral de la población en cada segmento...')   

dic = {'Trimestre': trimestre ,'Campeones': campeones , 'Leales': loyals, 'Potencialmente Leales': potential_loyal,
       'Reciente operativo': news, 'Prometedores': promising, 'No se pueden perder': cant_lost,'En Riesgo': risk ,
       'Necesitan Atencion': need_atention , 'Cercanos a Hibernar': close_hibernating , 'Hibernando': hibernating} 

df_lineas = pd.DataFrame(dic)
df_lineas.to_csv('1anio_porcentajes.csv', index = False)
# reverse the dataframe
df_lineas = df_lineas[::-1]
evolucion_trimestral_segmentos(df_lineas)
# Out:
# Ciclo--1:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-12-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7360
# La cantidad de comercios en el segmento En Riesgo es de: 2783
# La cantidad de comercios en el segmento Reciente operativo es de: 558
# La cantidad de comercios en el segmento Leales es de: 1354
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3796
# La cantidad de comercios en el segmento Hibernando es de: 6785
# La cantidad de comercios en el segmento Necesitan Atencion es de: 991
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 1453
# La cantidad de comercios en el segmento No se pueden perder es de: 425
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--2:
# La fecha de inicio es: 2020-01-25. La fecha final es: 2019-11-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 6249
# La cantidad de comercios en el segmento En Riesgo es de: 2852
# La cantidad de comercios en el segmento Reciente operativo es de: 623
# La cantidad de comercios en el segmento Leales es de: 2376
# La cantidad de comercios en el segmento Potencialmente Leales es de: 4677
# La cantidad de comercios en el segmento Hibernando es de: 6421
# La cantidad de comercios en el segmento Necesitan Atencion es de: 574
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 978
# La cantidad de comercios en el segmento No se pueden perder es de: 570
# La cantidad de comercios en el segmento Prometedores es de: 465
# =================================================================================================
# Ciclo--3:
# La fecha de inicio es: 2019-12-25. La fecha final es: 2019-10-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7287
# La cantidad de comercios en el segmento En Riesgo es de: 1631
# La cantidad de comercios en el segmento Reciente operativo es de: 936
# La cantidad de comercios en el segmento Leales es de: 1265
# La cantidad de comercios en el segmento Potencialmente Leales es de: 4884
# La cantidad de comercios en el segmento Hibernando es de: 5087
# La cantidad de comercios en el segmento Necesitan Atencion es de: 932
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 1546
# La cantidad de comercios en el segmento No se pueden perder es de: 296
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--4:
# La fecha de inicio es: 2019-11-25. La fecha final es: 2019-09-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 6728
# La cantidad de comercios en el segmento En Riesgo es de: 2604
# La cantidad de comercios en el segmento Reciente operativo es de: 474
# La cantidad de comercios en el segmento Leales es de: 1637
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3417
# La cantidad de comercios en el segmento Hibernando es de: 6771
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1012
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 1353
# La cantidad de comercios en el segmento No se pueden perder es de: 372
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--5:
# La fecha de inicio es: 2019-10-25. La fecha final es: 2019-08-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: