# %%
from rfm_deployment.rfm_model_V2_com import *
from itertools import product
import cx_Oracle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import datetime
import cairo
import gi
gi.require_version('Gtk', '3.0')
from gi.repository import Gtk

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
inicio = datetime.date(2020, 2, 25)
fin = datetime.date(2019, 3, 25)
months = -1

# %%
fecha_final = add_months(inicio, -2)
contador = 1


trimestre = []
campeones = []
loyals = []
potential_loyal = []
news = []
promising = []
cant_lost = []
risk = []
need_atention = []
close_hibernating = []
hibernating = []

while fecha_final >= fin :
   
    fi_int = datetime_to_integer(inicio)
    ff_int = datetime_to_integer(fecha_final)
    print(f'Ciclo--{contador}:')
    print(f'La fecha de inicio es: {inicio}. La fecha final es: {fecha_final}.' )
    fecha_out = str(ff_int) # Fecha límite inferior para el trimestre de interés
    fecha_in = str(fi_int)  # Fecha límite superior para el trimestre de interés
    label = 'PCA'
    df = pd.read_parquet(f'PCA-{fecha_in}--{fecha_out}.parquet')
    print('=================================================================================================')
    
    rfm_model = rfm_scoring(df, fecha_in, fecha_out, label)
    print('-------------------------------------------------------------------------------------------------')

    #rfm_corr = rfm_model[['RECENCIA', 'FRECUENCIA', 'MONTO']].corr()
    #print('La matriz de correlacion es:')
    #print(rfm_corr.corr())
    #print('-------------------------------------------------------------------------------------------------')
    
    #bins_R = 90
    #bins_F = 100
    #bins_M = 100
    #range_R = [0,90]
    #range_F = [0, 10000]
    #range_M = [0, 10000000]
    #histogramas(rfm_model['RECENCIA'], rfm_model['FRECUENCIA'], rfm_model['MONTO'], 
    #        bins_R, bins_F, bins_M, range_R, range_F, range_M)

    #EDA...
    #histogramas(rfm['RECENCIA'], rfm['FRECUENCIA'], rfm['MONTO'])
    #print('-------------------------------------------------------------------------------------------------')
    
    segmentar(rfm_model, fecha_in, fecha_out)
    rfm_segmentos, dic_cuit, rfm_segmentado = label_segmentos(rfm_model, fecha_in, fecha_out,label)
    
     #Creando listas para generar gráfico de lineas como función de los trimestres')
   
    entrada = datetime.datetime.strptime(f'{inicio}', '%Y-%m-%d').strftime('%d/%m/%Y')
    salida = datetime.datetime.strptime(f'{fecha_final}', '%Y-%m-%d').strftime('%d/%m/%Y')
   
    trimestre.append(f'{entrada}--{salida}')
    campeones.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Campeones'][['%']].iloc[0,0])
    loyals.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Leales'][['%']].iloc[0,0])
    potential_loyal.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Potencialmente Leales'][['%']].iloc[0,0])
    news.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Reciente operativo'][['%']].iloc[0,0])
    promising.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Prometedores'][['%']].iloc[0,0])
    cant_lost.append(rfm_segmentado[rfm_segmentado['Segment'] == 'No se pueden perder'][['%']].iloc[0,0])
    risk.append(rfm_segmentado[rfm_segmentado['Segment'] == 'En Riesgo'][['%']].iloc[0,0])
    need_atention.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Necesitan Atencion'][['%']].iloc[0,0])
    close_hibernating.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Cercanos a Hibernar'][['%']].iloc[0,0])
    hibernating.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Hibernando'][['%']].iloc[0,0])
      
   
    inicio = add_months(inicio, months)
    fecha_final = add_months(fecha_final, months)
    contador += 1
   
    print('=================================================================================================')
    
print('Evolución trimestral de la población en cada segmento...')   

dic = {'Trimestre': trimestre ,'Campeones': campeones , 'Leales': loyals, 'Potencialmente Leales': potential_loyal,
       'Reciente operativo': news, 'Prometedores': promising, 'No se pueden perder': cant_lost,'En Riesgo': risk ,
       'Necesitan Atencion': need_atention , 'Cercanos a Hibernar': close_hibernating , 'Hibernando': hibernating} 

df_lineas = pd.DataFrame(dic)
df_lineas.to_csv('1anio_porcentajes.csv', index = False)
# reverse the dataframe
df_lineas = df_lineas[::-1]
evolucion_trimestral_segmentos(df_lineas)
# Out:
# Ciclo--1:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-12-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 10108
# La cantidad de comercios en el segmento En Riesgo es de: 5333
# La cantidad de comercios en el segmento Reciente operativo es de: 713
# La cantidad de comercios en el segmento Leales es de: 8684
# La cantidad de comercios en el segmento Potencialmente Leales es de: 5540
# La cantidad de comercios en el segmento Hibernando es de: 15385
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2803
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 3575
# La cantidad de comercios en el segmento No se pueden perder es de: 457
# La cantidad de comercios en el segmento Prometedores es de: 735
# =================================================================================================
# Ciclo--2:
# La fecha de inicio es: 2020-01-25. La fecha final es: 2019-11-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 9708
# La cantidad de comercios en el segmento En Riesgo es de: 5096
# La cantidad de comercios en el segmento Reciente operativo es de: 698
# La cantidad de comercios en el segmento Leales es de: 9275
# La cantidad de comercios en el segmento Potencialmente Leales es de: 6269
# La cantidad de comercios en el segmento Hibernando es de: 15216
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2461
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 3219
# La cantidad de comercios en el segmento No se pueden perder es de: 478
# La cantidad de comercios en el segmento Prometedores es de: 922
# =================================================================================================
# Ciclo--3:
# La fecha de inicio es: 2019-12-25. La fecha final es: 2019-10-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 9115
# La cantidad de comercios en el segmento En Riesgo es de: 4050
# La cantidad de comercios en el segmento Reciente operativo es de: 511
# La cantidad de comercios en el segmento Leales es de: 8437
# La cantidad de comercios en el segmento Potencialmente Leales es de: 6809
# La cantidad de comercios en el segmento Hibernando es de: 14877
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1973
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2931
# La cantidad de comercios en el segmento No se pueden perder es de: 392
# La cantidad de comercios en el segmento Prometedores es de: 652
# =================================================================================================
# Ciclo--4:
# La fecha de inicio es: 2019-11-25. La fecha final es: 2019-09-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 8192
# La cantidad de comercios en el segmento En Riesgo es de: 4485
# La cantidad de comercios en el segmento Reciente operativo es de: 369
# La cantidad de comercios en el segmento Leales es de: 8878
# La cantidad de comercios en el segmento Potencialmente Leales es de: 6375
# La cantidad de comercios en el segmento Hibernando es de: 14850
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2252
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2955
# La cantidad de comercios en el segmento No se pueden perder es de: 327
# La cantidad de comercios en el segmento Prometedores es de: 742
# =================================================================================================
# Ciclo--5:
# La fecha de inicio es: 2019-10-25. La fecha final es: 2019-08-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 8195
# La cantidad de comercios en el segmento En Riesgo es de: 4444
# La cantidad de comercios en el segmento Reciente operativo es de: 506
# La cantidad de comercios en el segmento Leales es de: 9514
# La cantidad de comercios en el segmento Potencialmente Leales es de: 5492
# La cantidad de comercios en el segmento Hibernando es de: 15125
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2194
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 3433
# La cantidad de comercios en el segmento No se pueden perder es de: 376
# La cantidad de comercios en el segmento Prometedores es de: 634
# =================================================================================================
# Ciclo--6:
# La fecha de inicio es: 2019-09-25. La fecha final es: 2019-07-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 9104
# La cantidad de comercios en el segmento En Riesgo es de: 3646
# La cantidad de comercios en el segmento Reciente operativo es de: 581
# La cantidad de comercios en el segmento Leales es de: 8402
# La cantidad de comercios en el segmento Potencialmente Leales es de: 5827
# La cantidad de comercios en el segmento Hibernando es de: 15166
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2404
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 3917
# La cantidad de comercios en el segmento No se pueden perder es de: 279
# La cantidad de comercios en el segmento Prometedores es de: 739
# =================================================================================================
# Ciclo--7:
# La fecha de inicio es: 2019-08-25. La fecha final es: 2019-06-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7224
# La cantidad de comercios en el segmento En Riesgo es de: 5245
# La cantidad de comercios en el segmento Reciente operativo es de: 739
# La cantidad de comercios en el segmento Leales es de: 8634
# La cantidad de comercios en el segmento Potencialmente Leales es de: 5152
# La cantidad de comercios en el segmento Hibernando es de: 12590
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2414
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2962
# La cantidad de comercios en el segmento No se pueden perder es de: 410
# La cantidad de comercios en el segmento Prometedores es de: 1107
# =================================================================================================
# Ciclo--8:
# La fecha de inicio es: 2019-07-25. La fecha final es: 2019-05-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 6639
# La cantidad de comercios en el segmento En Riesgo es de: 4687
# La cantidad de comercios en el segmento Reciente operativo es de: 1111
# La cantidad de comercios en el segmento Leales es de: 6131
# La cantidad de comercios en el segmento Potencialmente Leales es de: 4996
# La cantidad de comercios en el segmento Hibernando es de: 9631
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1468
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2781
# La cantidad de comercios en el segmento No se pueden perder es de: 529
# La cantidad de comercios en el segmento Prometedores es de: 1098
# =================================================================================================
# Ciclo--9:
# La fecha de inicio es: 2019-06-25. La fecha final es: 2019-04-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7906
# La cantidad de comercios en el segmento En Riesgo es de: 3927
# La cantidad de comercios en el segmento Reciente operativo es de: 329
# La cantidad de comercios en el segmento Leales es de: 7802
# La cantidad de comercios en el segmento Potencialmente Leales es de: 5257
# La cantidad de comercios en el segmento Hibernando es de: 12753
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2243
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2341
# La cantidad de comercios en el segmento No se pueden perder es de: 266
# La cantidad de comercios en el segmento Prometedores es de: 558
# =================================================================================================
# Ciclo--10:
# La fecha de inicio es: 2019-05-25. La fecha final es: 2019-03-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7889
# La cantidad de comercios en el segmento En Riesgo es de: 3986
# La cantidad de comercios en el segmento Reciente operativo es de: 433
# La cantidad de comercios en el segmento Leales es de: 7650
# La cantidad de comercios en el segmento Potencialmente Leales es de: 4837
# La cantidad de comercios en el segmento Hibernando es de: 12299
# La cantidad de comercios en el segmento Necesitan Atencion es de: 2635
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2884
# La cantidad de comercios en el segmento No se pueden perder es de: 322
# La cantidad de comercios en el segmento Prometedores es de: 446
# =================================================================================================
# Evolución trimestral de la población en cada segmento...
