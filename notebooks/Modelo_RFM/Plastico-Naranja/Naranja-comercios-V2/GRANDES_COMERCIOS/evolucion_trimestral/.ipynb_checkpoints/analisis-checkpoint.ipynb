# %%
from rfm_deployment.rfm_model_V2_com import *
from itertools import product
import cx_Oracle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import datetime
import cairo
import gi
gi.require_version('Gtk', '3.0')
from gi.repository import Gtk

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
inicio = datetime.date(2020, 2, 25)
fin = datetime.date(2019, 3, 25)
months = -1

# %%
fecha_final = add_months(inicio, -2)
contador = 1


trimestre = []
campeones = []
loyals = []
potential_loyal = []
news = []
promising = []
cant_lost = []
risk = []
need_atention = []
close_hibernating = []
hibernating = []

while fecha_final >= fin :
   
    fi_int = datetime_to_integer(inicio)
    ff_int = datetime_to_integer(fecha_final)
    print(f'Ciclo--{contador}:')
    print(f'La fecha de inicio es: {inicio}. La fecha final es: {fecha_final}.' )
    fecha_out = str(ff_int) # Fecha límite inferior para el trimestre de interés
    fecha_in = str(fi_int)  # Fecha límite superior para el trimestre de interés
    label = 'GRANDES COMERCIOS'
    df = pd.read_parquet(f'GRANDES COMERCIOS-{fecha_in}--{fecha_out}.parquet')
    print('=================================================================================================')
    
    rfm_model = rfm_scoring(df, fecha_in, fecha_out, label)
    print('-------------------------------------------------------------------------------------------------')

    #rfm_corr = rfm_model[['RECENCIA', 'FRECUENCIA', 'MONTO']].corr()
    #print('La matriz de correlacion es:')
    #print(rfm_corr.corr())
    #print('-------------------------------------------------------------------------------------------------')
    
    #bins_R = 90
    #bins_F = 100
    #bins_M = 100
    #range_R = [0,90]
    #range_F = [0, 10000]
    #range_M = [0, 10000000]
    #histogramas(rfm_model['RECENCIA'], rfm_model['FRECUENCIA'], rfm_model['MONTO'], 
    #        bins_R, bins_F, bins_M, range_R, range_F, range_M)

    #EDA...
    #histogramas(rfm['RECENCIA'], rfm['FRECUENCIA'], rfm['MONTO'])
    #print('-------------------------------------------------------------------------------------------------')
    
    segmentar(rfm_model, fecha_in, fecha_out)
    rfm_segmentos, dic_cuit, rfm_segmentado = label_segmentos(rfm_model, fecha_in, fecha_out,label)
    
     #Creando listas para generar gráfico de lineas como función de los trimestres')
   
    entrada = datetime.datetime.strptime(f'{inicio}', '%Y-%m-%d').strftime('%d/%m/%Y')
    salida = datetime.datetime.strptime(f'{fecha_final}', '%Y-%m-%d').strftime('%d/%m/%Y')
   
    trimestre.append(f'{entrada}--{salida}')
    campeones.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Campeones'][['%']].iloc[0,0])
    loyals.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Leales'][['%']].iloc[0,0])
    potential_loyal.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Potencialmente Leales'][['%']].iloc[0,0])
    news.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Reciente operativo'][['%']].iloc[0,0])
    promising.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Prometedores'][['%']].iloc[0,0])
    cant_lost.append(rfm_segmentado[rfm_segmentado['Segment'] == 'No se pueden perder'][['%']].iloc[0,0])
    risk.append(rfm_segmentado[rfm_segmentado['Segment'] == 'En Riesgo'][['%']].iloc[0,0])
    need_atention.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Necesitan Atencion'][['%']].iloc[0,0])
    close_hibernating.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Cercanos a Hibernar'][['%']].iloc[0,0])
    hibernating.append(rfm_segmentado[rfm_segmentado['Segment'] == 'Hibernando'][['%']].iloc[0,0])
      
   
    inicio = add_months(inicio, months)
    fecha_final = add_months(fecha_final, months)
    contador += 1
   
    print('=================================================================================================')
    
print('Evolución trimestral de la población en cada segmento...')   

dic = {'Trimestre': trimestre ,'Campeones': campeones , 'Leales': loyals, 'Potencialmente Leales': potential_loyal,
       'Reciente operativo': news, 'Prometedores': promising, 'No se pueden perder': cant_lost,'En Riesgo': risk ,
       'Necesitan Atencion': need_atention , 'Cercanos a Hibernar': close_hibernating , 'Hibernando': hibernating} 

df_lineas = pd.DataFrame(dic)
df_lineas.to_csv('1anio_porcentajes.csv', index = False)
# reverse the dataframe
df_lineas = df_lineas[::-1]
evolucion_trimestral_segmentos(df_lineas)
# Out:
# Ciclo--1:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-12-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 306
# La cantidad de comercios en el segmento En Riesgo es de: 47
# La cantidad de comercios en el segmento Reciente operativo es de: 4
# La cantidad de comercios en el segmento Leales es de: 66
# La cantidad de comercios en el segmento Potencialmente Leales es de: 88
# La cantidad de comercios en el segmento Hibernando es de: 299
# La cantidad de comercios en el segmento Necesitan Atencion es de: 100
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 74
# La cantidad de comercios en el segmento No se pueden perder es de: 11
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--2:
# La fecha de inicio es: 2020-01-25. La fecha final es: 2019-11-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 370
# La cantidad de comercios en el segmento En Riesgo es de: 66
# La cantidad de comercios en el segmento Reciente operativo es de: 8
# La cantidad de comercios en el segmento Leales es de: 18
# La cantidad de comercios en el segmento Potencialmente Leales es de: 136
# La cantidad de comercios en el segmento Hibernando es de: 311
# La cantidad de comercios en el segmento Necesitan Atencion es de: 47
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 46
# La cantidad de comercios en el segmento No se pueden perder es de: 0
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--3:
# La fecha de inicio es: 2019-12-25. La fecha final es: 2019-10-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 351
# La cantidad de comercios en el segmento En Riesgo es de: 73
# La cantidad de comercios en el segmento Reciente operativo es de: 40
# La cantidad de comercios en el segmento Leales es de: 0
# La cantidad de comercios en el segmento Potencialmente Leales es de: 245
# La cantidad de comercios en el segmento Hibernando es de: 249
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 11
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--4:
# La fecha de inicio es: 2019-11-25. La fecha final es: 2019-09-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 299
# La cantidad de comercios en el segmento En Riesgo es de: 48
# La cantidad de comercios en el segmento Reciente operativo es de: 3
# La cantidad de comercios en el segmento Leales es de: 79
# La cantidad de comercios en el segmento Potencialmente Leales es de: 186
# La cantidad de comercios en el segmento Hibernando es de: 278
# La cantidad de comercios en el segmento Necesitan Atencion es de: 34
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 40
# La cantidad de comercios en el segmento No se pueden perder es de: 2
# La cantidad de comercios en el segmento Prometedores es de: 10
# =================================================================================================
# Ciclo--5:
# La fecha de inicio es: 2019-10-25. La fecha final es: 2019-08-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 342
# La cantidad de comercios en el segmento En Riesgo es de: 50
# La cantidad de comercios en el segmento Reciente operativo es de: 9
# La cantidad de comercios en el segmento Leales es de: 25
# La cantidad de comercios en el segmento Potencialmente Leales es de: 121
# La cantidad de comercios en el segmento Hibernando es de: 299
# La cantidad de comercios en el segmento Necesitan Atencion es de: 68
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: