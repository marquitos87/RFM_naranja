# %%
from rfm_deployment.rfm_model_V2_com import *
from itertools import product
import cx_Oracle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import datetime
import cairo
import gi
gi.require_version('Gtk', '3.0')
from gi.repository import Gtk

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
inicio = datetime.date(2020, 2, 25)
fin = datetime.date(2019, 3, 25)
months = -1

# %%
fecha_final = add_months(inicio, -2)
contador = 1

while fecha_final >= fin :
   
    fi_int = datetime_to_integer(inicio)
    ff_int = datetime_to_integer(fecha_final)
    print(f'Ciclo--{contador}:')
    print(f'La fecha de inicio es: {inicio}. La fecha final es: {fecha_final}.' )
    fecha_out = str(ff_int) # Fecha límite inferior para el trimestre de interés
    fecha_in = str(fi_int)  # Fecha límite superior para el trimestre de interés
    label = 'TOP'
    df = pd.read_parquet(f'TOP-{fecha_in}--{fecha_out}.parquet')
    print('=================================================================================================')
    
    rfm_model = rfm_scoring(df, fecha_in, fecha_out, label)
    print('-------------------------------------------------------------------------------------------------')

    #rfm_corr = rfm_model[['RECENCIA', 'FRECUENCIA', 'MONTO']].corr()
    #print('La matriz de correlacion es:')
    #print(rfm_corr.corr())
    #print('-------------------------------------------------------------------------------------------------')
    
    #bins_R = 90
    #bins_F = 100
    #bins_M = 100
    #range_R = [0,90]
    #range_F = [0, 10000]
    #range_M = [0, 10000000]
    #histogramas(rfm_model['RECENCIA'], rfm_model['FRECUENCIA'], rfm_model['MONTO'], 
    #        bins_R, bins_F, bins_M, range_R, range_F, range_M)

    #EDA...
    #histogramas(rfm['RECENCIA'], rfm['FRECUENCIA'], rfm['MONTO'])
    #print('-------------------------------------------------------------------------------------------------')
    
    segmentar(rfm_model, fecha_in, fecha_out)
    rfm_segmentos, dic_cuit, rfm_segmentado = label_segmentos(rfm_model, fecha_in, fecha_out,label)
    
   
    #inicio = add_months(inicio, months)
    fecha_final = add_months(fecha_final, months)
    contador += 1
   
    print('=================================================================================================')
# Out:
# Ciclo--1:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-12-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1739
# La cantidad de comercios en el segmento En Riesgo es de: 305
# La cantidad de comercios en el segmento Reciente operativo es de: 78
# La cantidad de comercios en el segmento Leales es de: 1293
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2533
# La cantidad de comercios en el segmento Hibernando es de: 1545
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 38
# La cantidad de comercios en el segmento Prometedores es de: 430
# =================================================================================================
# Ciclo--2:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-11-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1747
# La cantidad de comercios en el segmento En Riesgo es de: 315
# La cantidad de comercios en el segmento Reciente operativo es de: 74
# La cantidad de comercios en el segmento Leales es de: 1302
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2531
# La cantidad de comercios en el segmento Hibernando es de: 1576
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 40
# La cantidad de comercios en el segmento Prometedores es de: 419
# =================================================================================================
# Ciclo--3:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-10-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1740
# La cantidad de comercios en el segmento En Riesgo es de: 340
# La cantidad de comercios en el segmento Reciente operativo es de: 70
# La cantidad de comercios en el segmento Leales es de: 1321
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2528
# La cantidad de comercios en el segmento Hibernando es de: 1592
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 40
# La cantidad de comercios en el segmento Prometedores es de: 418
# =================================================================================================
# Ciclo--4:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-09-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1751
# La cantidad de comercios en el segmento En Riesgo es de: 354
# La cantidad de comercios en el segmento Reciente operativo es de: 72
# La cantidad de comercios en el segmento Leales es de: 1321
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2526
# La cantidad de comercios en el segmento Hibernando es de: 1609
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 40
# La cantidad de comercios en el segmento Prometedores es de: 410
# =================================================================================================
# Ciclo--5:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-08-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1760
# La cantidad de comercios en el segmento En Riesgo es de: 358
# La cantidad de comercios en el segmento Reciente operativo es de: 72
# La cantidad de comercios en el segmento Leales es de: 1324
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2513
# La cantidad de comercios en el segmento Hibernando es de: 1633
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 44
# La cantidad de comercios en el segmento Prometedores es de: 415
# =================================================================================================
# Ciclo--6:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-07-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1763
# La cantidad de comercios en el segmento En Riesgo es de: 368
# La cantidad de comercios en el segmento Reciente operativo es de: 73
# La cantidad de comercios en el segmento Leales es de: 1334
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2511
# La cantidad de comercios en el segmento Hibernando es de: 1654
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 44
# La cantidad de comercios en el segmento Prometedores es de: 407
# =================================================================================================
# Ciclo--7:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-06-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1766
# La cantidad de comercios en el segmento En Riesgo es de: 376
# La cantidad de comercios en el segmento Reciente operativo es de: 71
# La cantidad de comercios en el segmento Leales es de: 1327
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2513
# La cantidad de comercios en el segmento Hibernando es de: 1645
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 46
# La cantidad de comercios en el segmento Prometedores es de: 411
# =================================================================================================
# Ciclo--8:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-05-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1765
# La cantidad de comercios en el segmento En Riesgo es de: 397
# La cantidad de comercios en el segmento Reciente operativo es de: 75
# La cantidad de comercios en el segmento Leales es de: 1322
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2513
# La cantidad de comercios en el segmento Hibernando es de: 1628
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 43
# La cantidad de comercios en el segmento Prometedores es de: 413
# =================================================================================================
# Ciclo--9:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-04-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1834
# La cantidad de comercios en el segmento En Riesgo es de: 463
# La cantidad de comercios en el segmento Reciente operativo es de: 69
# La cantidad de comercios en el segmento Leales es de: 1451
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2594
# La cantidad de comercios en el segmento Hibernando es de: 1853
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 52
# La cantidad de comercios en el segmento Prometedores es de: 407
# =================================================================================================
# Ciclo--10:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-03-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 1836
# La cantidad de comercios en el segmento En Riesgo es de: 469
# La cantidad de comercios en el segmento Reciente operativo es de: 74
# La cantidad de comercios en el segmento Leales es de: 1445
# La cantidad de comercios en el segmento Potencialmente Leales es de: 2588
# La cantidad de comercios en el segmento Hibernando es de: 1850
# La cantidad de comercios en el segmento Necesitan Atencion es de: 0
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 0
# La cantidad de comercios en el segmento No se pueden perder es de: 51
# La cantidad de comercios en el segmento Prometedores es de: 412
# =================================================================================================

# %%
fecha_out = '20191225'
fecha_in = '20200225'
label = 'TOP'

rfm_grafico = pd.read_csv(f'{label}-segment-plot-{fecha_in}--{fecha_out}.csv') 
df = pd.read_csv(f'{label}-rfm-segmentos-{fecha_in}--{fecha_out}.csv')

rfm_prom = df[['RECENCIA', 'FRECUENCIA', 'MONTO', 'Segment']].groupby(['Segment']).median().round(2)
rfm_prom = rfm_prom.rename(columns = {'RECENCIA': 'R_MEDIAN', 'FRECUENCIA': 'F_MEDIAN', 'MONTO': 'M_MEDIAN'})
rfm_prom = rfm_prom.reset_index() 
rfm_x_grafico = pd.merge(rfm_prom, rfm_grafico, on='Segment', how='right')
rfm_x_grafico['R_MEDIAN'].fillna('NA', inplace=True)
rfm_x_grafico['F_MEDIAN'].fillna('NA', inplace=True)
rfm_x_grafico['M_MEDIAN'].fillna('NA', inplace=True)
rfm_x_grafico['%'] = rfm_x_grafico['%'].apply(lambda x : str(x)+'%')
rfm_x_grafico['cantidad'] = rfm_x_grafico['cantidad'].apply(lambda x : str(x))
rfm_x_grafico['R_MEDIAN'] = rfm_x_grafico['R_MEDIAN'].apply(lambda x : str(x))
rfm_x_grafico['F_MEDIAN'] = rfm_x_grafico['F_MEDIAN'].apply(lambda x : str(x))
rfm_x_grafico['M_MEDIAN'] = rfm_x_grafico['M_MEDIAN'].apply(lambda x : str(x))
rfm_percentaje_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico['%']))
rfm_cantidad_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.cantidad))
rfm_R_MEDIAN_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.R_MEDIAN))
rfm_F_MEDIAN_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.F_MEDIAN))
rfm_M_MEDIAN_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.M_MEDIAN))

app = RFM_graph()
app.porcentajes = rfm_percentaje_dic
app.cantidad = rfm_cantidad_dic
app.R_MEDIAN = rfm_R_MEDIAN_dic
app.F_MEDIAN = rfm_F_MEDIAN_dic
app.M_MEDIAN = rfm_M_MEDIAN_dic
Gtk.main()

# %%
df1 = pd.read_parquet(f'TOP-20200225--20191225.parquet')
df2 = pd.read_parquet(f'TOP-20200225--20190325.parquet')

# %%
fecha_out1 = '20191225'
fecha_in1 = '20200225'
label = 'TOP'
rfm1 = rfm_scoring(df1, fecha_in1, fecha_out1, label)
fecha_out2 = '20190725'
fecha_in2 = '20200225'
label = 'TOP'
rfm2 = rfm_scoring(df2, fecha_in2, fecha_out2, label)

# %%
data1 = segmentar(rfm1, fecha_in1, fecha_out1)
data2 = segmentar(rfm2, fecha_in2, fecha_out2)

# %%
data1['%'].corr(data2['%'], method='pearson')
# Out:
# 0.9918136980841453

# %%
data1
# Out:
#     RFMScore  cantidad     %
# 0        111       521  6.54
# 1        112       135  1.70
# 2        113        64  0.80
# 3        114        28  0.35
# 4        115         1  0.01
# ..       ...       ...   ...
# 120      551         0  0.00
# 121      552        13  0.16
# 122      553        83  1.04
# 123      554       310  3.89
# 124      555       654  8.22
#
# [125 rows x 3 columns]

# %%
data2
# Out:
#     RFMScore  cantidad     %
# 0        111       679  7.78
# 1        112       172  1.97
# 2        113        73  0.84
# 3        114        22  0.25
# 4        115         0  0.00
# ..       ...       ...   ...
# 120      551         0  0.00
# 121      552        10  0.11
# 122      553        97  1.11
# 123      554       330  3.78
# 124      555       710  8.14
#
# [125 rows x 3 columns]
