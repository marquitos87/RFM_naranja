# %%
from rfm_deployment.rfm_model_V2_com import *
from itertools import product
import cx_Oracle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import datetime
import cairo
import gi
gi.require_version('Gtk', '3.0')
from gi.repository import Gtk

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)

# %%
inicio = datetime.date(2020, 2, 25)
fin = datetime.date(2019, 3, 25)
months = -1

# %%
fecha_final = add_months(inicio, -2)
contador = 1

while fecha_final >= fin :
   
    fi_int = datetime_to_integer(inicio)
    ff_int = datetime_to_integer(fecha_final)
    print(f'Ciclo--{contador}:')
    print(f'La fecha de inicio es: {inicio}. La fecha final es: {fecha_final}.' )
    fecha_out = str(ff_int) # Fecha límite inferior para el trimestre de interés
    fecha_in = str(fi_int)  # Fecha límite superior para el trimestre de interés
    label = 'CA'
    df = pd.read_parquet(f'CA-{fecha_in}--{fecha_out}.parquet')
    print('=================================================================================================')
    
    rfm_model = rfm_scoring(df, fecha_in, fecha_out, label)
    print('-------------------------------------------------------------------------------------------------')

    #rfm_corr = rfm_model[['RECENCIA', 'FRECUENCIA', 'MONTO']].corr()
    #print('La matriz de correlacion es:')
    #print(rfm_corr.corr())
    #print('-------------------------------------------------------------------------------------------------')
    
    #bins_R = 90
    #bins_F = 100
    #bins_M = 100
    #range_R = [0,90]
    #range_F = [0, 10000]
    #range_M = [0, 10000000]
    #histogramas(rfm_model['RECENCIA'], rfm_model['FRECUENCIA'], rfm_model['MONTO'], 
    #        bins_R, bins_F, bins_M, range_R, range_F, range_M)

    #EDA...
    #histogramas(rfm['RECENCIA'], rfm['FRECUENCIA'], rfm['MONTO'])
    #print('-------------------------------------------------------------------------------------------------')
    
    segmentar(rfm_model, fecha_in, fecha_out)
    rfm_segmentos, dic_cuit, rfm_segmentado = label_segmentos(rfm_model, fecha_in, fecha_out,label)
    
   
    #inicio = add_months(inicio, months)
    fecha_final = add_months(fecha_final, months)
    contador += 1
   
    print('=================================================================================================')
# Out:
# Ciclo--1:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-12-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7360
# La cantidad de comercios en el segmento En Riesgo es de: 2783
# La cantidad de comercios en el segmento Reciente operativo es de: 558
# La cantidad de comercios en el segmento Leales es de: 1354
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3796
# La cantidad de comercios en el segmento Hibernando es de: 6785
# La cantidad de comercios en el segmento Necesitan Atencion es de: 991
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 1453
# La cantidad de comercios en el segmento No se pueden perder es de: 425
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--2:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-11-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7374
# La cantidad de comercios en el segmento En Riesgo es de: 2887
# La cantidad de comercios en el segmento Reciente operativo es de: 536
# La cantidad de comercios en el segmento Leales es de: 1383
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3816
# La cantidad de comercios en el segmento Hibernando es de: 7009
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1000
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 1422
# La cantidad de comercios en el segmento No se pueden perder es de: 440
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--3:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-10-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7427
# La cantidad de comercios en el segmento En Riesgo es de: 2082
# La cantidad de comercios en el segmento Reciente operativo es de: 537
# La cantidad de comercios en el segmento Leales es de: 1927
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3773
# La cantidad de comercios en el segmento Hibernando es de: 6188
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1549
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2307
# La cantidad de comercios en el segmento No se pueden perder es de: 315
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--4:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-09-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7600
# La cantidad de comercios en el segmento En Riesgo es de: 2130
# La cantidad de comercios en el segmento Reciente operativo es de: 510
# La cantidad de comercios en el segmento Leales es de: 1985
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3819
# La cantidad de comercios en el segmento Hibernando es de: 6397
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1544
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2315
# La cantidad de comercios en el segmento No se pueden perder es de: 332
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--5:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-08-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7612
# La cantidad de comercios en el segmento En Riesgo es de: 2204
# La cantidad de comercios en el segmento Reciente operativo es de: 492
# La cantidad de comercios en el segmento Leales es de: 1994
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3829
# La cantidad de comercios en el segmento Hibernando es de: 6567
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1561
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2293
# La cantidad de comercios en el segmento No se pueden perder es de: 346
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--6:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-07-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7647
# La cantidad de comercios en el segmento En Riesgo es de: 2269
# La cantidad de comercios en el segmento Reciente operativo es de: 481
# La cantidad de comercios en el segmento Leales es de: 2024
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3811
# La cantidad de comercios en el segmento Hibernando es de: 6674
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1539
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2288
# La cantidad de comercios en el segmento No se pueden perder es de: 366
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--7:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-06-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7648
# La cantidad de comercios en el segmento En Riesgo es de: 2343
# La cantidad de comercios en el segmento Reciente operativo es de: 499
# La cantidad de comercios en el segmento Leales es de: 2003
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3792
# La cantidad de comercios en el segmento Hibernando es de: 6598
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1571
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2277
# La cantidad de comercios en el segmento No se pueden perder es de: 369
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--8:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-05-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 7613
# La cantidad de comercios en el segmento En Riesgo es de: 2363
# La cantidad de comercios en el segmento Reciente operativo es de: 517
# La cantidad de comercios en el segmento Leales es de: 1983
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3809
# La cantidad de comercios en el segmento Hibernando es de: 6568
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1567
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2301
# La cantidad de comercios en el segmento No se pueden perder es de: 380
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--9:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-04-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 8134
# La cantidad de comercios en el segmento En Riesgo es de: 2631
# La cantidad de comercios en el segmento Reciente operativo es de: 495
# La cantidad de comercios en el segmento Leales es de: 2116
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3916
# La cantidad de comercios en el segmento Hibernando es de: 7290
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1658
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2303
# La cantidad de comercios en el segmento No se pueden perder es de: 399
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================
# Ciclo--10:
# La fecha de inicio es: 2020-02-25. La fecha final es: 2019-03-25.
# =================================================================================================
# -------------------------------------------------------------------------------------------------
# La cantidad de comercios en el segmento Campeones es de: 8144
# La cantidad de comercios en el segmento En Riesgo es de: 2621
# La cantidad de comercios en el segmento Reciente operativo es de: 490
# La cantidad de comercios en el segmento Leales es de: 2099
# La cantidad de comercios en el segmento Potencialmente Leales es de: 3911
# La cantidad de comercios en el segmento Hibernando es de: 7294
# La cantidad de comercios en el segmento Necesitan Atencion es de: 1680
# La cantidad de comercios en el segmento Cercanos a Hibernar es de: 2298
# La cantidad de comercios en el segmento No se pueden perder es de: 405
# La cantidad de comercios en el segmento Prometedores es de: 0
# =================================================================================================

# %%
fecha_out = '20191225'
fecha_in = '20200225'
label = 'CA'

rfm_grafico = pd.read_csv(f'{label}-segment-plot-{fecha_in}--{fecha_out}.csv') 
df = pd.read_csv(f'{label}-rfm-segmentos-{fecha_in}--{fecha_out}.csv')

rfm_prom = df[['RECENCIA', 'FRECUENCIA', 'MONTO', 'Segment']].groupby(['Segment']).median().round(2)
rfm_prom = rfm_prom.rename(columns = {'RECENCIA': 'R_MEDIAN', 'FRECUENCIA': 'F_MEDIAN', 'MONTO': 'M_MEDIAN'})
rfm_prom = rfm_prom.reset_index() 
rfm_x_grafico = pd.merge(rfm_prom, rfm_grafico, on='Segment', how='right')
rfm_x_grafico['R_MEDIAN'].fillna('NA', inplace=True)
rfm_x_grafico['F_MEDIAN'].fillna('NA', inplace=True)
rfm_x_grafico['M_MEDIAN'].fillna('NA', inplace=True)
rfm_x_grafico['%'] = rfm_x_grafico['%'].apply(lambda x : str(x)+'%')
rfm_x_grafico['cantidad'] = rfm_x_grafico['cantidad'].apply(lambda x : str(x))
rfm_x_grafico['R_MEDIAN'] = rfm_x_grafico['R_MEDIAN'].apply(lambda x : str(x))
rfm_x_grafico['F_MEDIAN'] = rfm_x_grafico['F_MEDIAN'].apply(lambda x : str(x))
rfm_x_grafico['M_MEDIAN'] = rfm_x_grafico['M_MEDIAN'].apply(lambda x : str(x))
rfm_percentaje_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico['%']))
rfm_cantidad_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.cantidad))
rfm_R_MEDIAN_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.R_MEDIAN))
rfm_F_MEDIAN_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.F_MEDIAN))
rfm_M_MEDIAN_dic = dict(zip(rfm_x_grafico.Segment, rfm_x_grafico.M_MEDIAN))

app = RFM_graph()
app.porcentajes = rfm_percentaje_dic
app.cantidad = rfm_cantidad_dic
app.R_MEDIAN = rfm_R_MEDIAN_dic
app.F_MEDIAN = rfm_F_MEDIAN_dic
app.M_MEDIAN = rfm_M_MEDIAN_dic
Gtk.main()

# %%
df1 = pd.read_parquet(f'CA-20200225--20191225.parquet')
df2 = pd.read_parquet(f'CA-20200225--20190325.parquet')

# %%
fecha_out1 = '20191225'
fecha_in1 = '20200225'
label = 'CA'
rfm1 = rfm_scoring(df1, fecha_in1, fecha_out1, label)
fecha_out2 = '20190725'
fecha_in2 = '20200225'
label = 'CA'
rfm2 = rfm_scoring(df2, fecha_in2, fecha_out2, label)

# %%
data1 = segmentar(rfm1, fecha_in1, fecha_out1)
data2 = segmentar(rfm2, fecha_in2, fecha_out2)

# %%
data1['%'].corr(data2['%'], method='pearson')
# Out:
# 0.9892597510436584
