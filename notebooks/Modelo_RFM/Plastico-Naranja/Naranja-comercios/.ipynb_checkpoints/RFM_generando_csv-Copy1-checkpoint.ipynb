# %%
from rfm_deployment.query_trimestral_comercios import *
import cx_Oracle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import datetime
import cairo
import gi
gi.require_version('Gtk', '3.0')
from gi.repository import Gtk

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)
#pd.set_option('display.max_rows', 500)

# %%
con = cx_Oracle.connect('MMONTERO_DIS/Data1234@//cluster-dwhAIX-scan:1521/dwh_app_service', encoding = 'utf8')
#Acceso al data Warehouse @DWTNPROD_AIX.WORLD desde fuera de Naranja

# %%
cur = con.cursor() #creo un cursor

# %%
inicio = datetime.date(2020, 1, 25)
fin = datetime.date(2019, 11, 25)
months = -1

# %%
fecha_final = add_months(inicio, -2)
contador = 1

while fecha_final >= fin :
    
    fi_int = datetime_to_integer(inicio)
    ff_int = datetime_to_integer(fecha_final)
    print(f'Ciclo--{contador}:')
    print(f'La fecha de inicio es: {inicio}. La fecha final es: {fecha_final}.' )
    fecha_init = inicio.strftime('%d/%m/%Y')
    fecha_init_month = inicio.strftime('%m/%Y')
    fecha_end = add_months(fecha_final, months).strftime('%d/%m/%Y')
    query = f_query(fi_int, ff_int, fecha_init, fecha_init_month, fecha_end)
    fecha_out = str(ff_int)
    fecha_in = str(fi_int)
    df = consulta_DW(query, cur, fecha_in, fecha_out)
    print('=================================================================================================')

    inicio = add_months(inicio, months)
    fecha_final = add_months(fecha_final, months)
    contador += 1
# Out:
# Ciclo--1:
# La fecha de inicio es: 2020-01-25. La fecha final es: 2019-11-25.

# %%
df1 = pd.read_parquet('20200125--20191125.parquet')

# %%
df1.shape
# Out:
# (5886944, 9)

# %%
df1
# Out:
#          DIM_TIEMPOS         CUIT              RUBRO_DESCRIPCION  \
# 0           20200125  30703088534          MEDIO DE PAGO VIRTUAL
# 1           20200125  30714600288          MEDIO DE PAGO VIRTUAL
# 2           20200125  20142735459       ELECTRICIDAD-ILUMINACION
# 3           20200125  30590360763                   FERRETERIAS.
# 4           20200125  30709284041                      FARMACIAS
# ...              ...          ...                            ...
# 5886939     20200125  20132851388                         OPTICA
# 5886940     20200125  30685849751  HIPERMERCADOS Y SUPERMERCADOS
# 5886941     20200125  30590360763  HIPERMERCADOS Y SUPERMERCADOS
# 5886942     20200125  30590360763  HIPERMERCADOS Y SUPERMERCADOS
# 5886943     20200125  30526133885  HIPERMERCADOS Y SUPERMERCADOS
#
#         FECHA_CONTRATO PROVINCIA_DESCRIPCION  TIPO_VENTA  IMPORTE MONEDA  \
# 0           2015-05-28       Capital Federal  PRESENCIAL  7199.00   Zeta
# 1           2017-06-13       Capital Federal  PRESENCIAL   890.00   Zeta
# 2           2018-05-14              La Rioja  PRESENCIAL  1225.00   Zeta
# 3           2010-02-18          Buenos Aires  PRESENCIAL  2990.00  Pesos
# 4           2006-10-20               Córdoba  PRESENCIAL  1020.23  Pesos
# ...                ...                   ...         ...      ...    ...
# 5886939     1999-12-16             Río Negro  PRESENCIAL  6600.00   Zeta
# 5886940     2017-09-18       Capital Federal  PRESENCIAL   145.58   Zeta
# 5886941     2018-06-14          Buenos Aires  PRESENCIAL   807.73   Zeta
# 5886942     2018-06-14          Buenos Aires  PRESENCIAL  1444.87   Zeta
# 5886943     2003-03-13              Santa Fe  PRESENCIAL  2597.68   Zeta
#
#              FECHA
# 0       2020-01-03
# 1       2020-01-10
# 2       2020-01-11
# 3       2020-01-19
# 4       2020-01-14
# ...            ...
# 5886939 2020-01-14
# 5886940 2019-12-29
# 5886941 2020-01-07
# 5886942 2020-01-24
# 5886943 2020-01-09
#
# [5886944 rows x 9 columns]
